# %%
import pandas as pd 

df = pd.concat( 
    map(pd.read_csv, ['Cars_Kolkata.csv', 'Cars_Mumbai.csv', 'Cars_Delhi.csv', 'Cars_Bangalore.csv']), ignore_index=True) 
df.to_csv('CARS24.csv', index=False)
df.tail(20)
# Out:
#                                         Name                            Model  \
# 2905           KIA SELTOS HTX IVT 1.5 PETROL        SELTOS HTX IVT 1.5 PETROL
# 2906                         Toyota Glanza V                         Glanza V
# 2907                  Maruti Celerio ZXI (O)                  Celerio ZXI (O)
# 2908       Hyundai Elite i20 SPORTZ PLUS 1.2        Elite i20 SPORTZ PLUS 1.2
# 2909   Hyundai Creta SX 1.6 PETROL DUAL TONE    Creta SX 1.6 PETROL DUAL TONE
# 2910            Hyundai Elite i20 SPORTZ 1.2             Elite i20 SPORTZ 1.2
# 2911  Maruti Grand Vitara SIGMA SMART HYBRID  Grand Vitara SIGMA SMART HYBRID
# 2912                      Mahindra XUV500 W8                        XUV500 W8
# 2913                   Tata Tiago XZA PETROL                 Tiago XZA PETROL
# 2914                  Renault Duster RXS CVT                   Duster RXS CVT
# 2915                  Renault Duster RXS CVT                   Duster RXS CVT
# ...
